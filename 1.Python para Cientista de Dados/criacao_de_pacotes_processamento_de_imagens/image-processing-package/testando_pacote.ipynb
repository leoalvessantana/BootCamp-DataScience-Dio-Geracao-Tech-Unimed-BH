# %%
from image_processing.utils import io, plot
from image_processing.processing import combination, transformation

# %%
imagem1 = io.read_image("ceu-cinza.png")
imagem2 = io.read_image("ceu-estrelado.jpg")

# %%
plot.plot_image(imagem1)
plot.plot_image(imagem2)

# %%
imagem_resultante = combination.transfer_histogram(imagem1, imagem2)
plot.plot_image(imagem_resultante)
